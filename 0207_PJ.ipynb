# %%
pwd
# Out:
# '/Users/Kimseunghyun/KDT'

# %%
import pandas as pd

man_total = './pop/manPop_2022.csv'
man_total_data=pd.read_csv(man_total)
man_total_data.head()
# Out:
#     행정구역  2022년1월_남자 인구수  2022년2월_남자 인구수  2022년3월_남자 인구수  2022년4월_남자 인구수  \
# 0  서울특별시         4615631         4615823         4613910         4610082
# 1  부산광역시         1638207         1637111         1634958         1633170
# 2  대구광역시         1174667         1173039         1172632         1171451
# 3  인천광역시         1476663         1477432         1478272         1478514
# 4  광주광역시          713037          712199          711289          710524
#
#    2022년5월_남자 인구수  2022년6월_남자 인구수  2022년7월_남자 인구수  2022년8월_남자 인구수  \
# 0         4607440         4605655         4604405         4601295
# 1         1631825         1630944         1629643         1627821
# 2         1170309         1169571         1168845         1167564
# 3         1479428         1480432         1482177         1483370
# 4          710062          709685          709305          709090
#
#    2022년9월_남자 인구수  2022년10월_남자 인구수  2022년11월_남자 인구수  2022년12월_남자 인구수  \
# 0         4582361          4578459          4574781          4570048
# 1         1623784          1622749          1621486          1619915
# 2         1165326          1164728          1164024          1162865
# 3         1481896          1483026          1484103          1485175
# 4          708248           708119           707815           707299
#
#           위도          경도
# 0  37.566491  126.977945
# 1  35.179805  129.074774
# 2  35.872873  128.601429
# 3  37.456191  126.705228
# 4  35.160198  126.851297

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

man_total = './pop/manPop_2022.csv'
man_total_data=pd.read_csv(man_total)
tenmillion_df= man_total_data[man_total_data['2022년12월_남자 인구수'] >= 1000000][['행정구역', '2022년12월_남자 인구수']]
tenmillion_df 

plt.rc('font', family='Apple SD Gothic Neo')
plt.bar(tenmillion_df['행정구역'], tenmillion_df['2022년12월_남자 인구수'], color='blue', alpha=0.5)
# Out:
# <BarContainer object of 8 artists>

# %%
months = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
man_total_data_list = []
for month in months:
    column_name = f'2022년{month}_남자 인구수'
    man_total_data_list.append(man_total_data[column_name].sum())
man_total_data_list
# Out:
# [25742528,
#  25738197,
#  25730584,
#  25721053,
#  25715591,
#  25711784,
#  25708650,
#  25699579,
#  25653998,
#  25649509,
#  25643889,
#  25636951]

# %%
plt.plot(months, man_total_data_list, color = 'orange', marker = '*')
plt.title('2022 남자 총 인구수 변동')
# Out:
# Text(0.5, 1.0, '2022 남자 총 인구수 변동')

# %%
ratio = tenmillion_df['2022년12월_남자 인구수']
labels = tenmillion_df['행정구역']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
ratio
# Out:
# 0     4570048
# 1     1619915
# 2     1162865
# 3     1485175
# 8     6839276
# 11    1086632
# 14    1311881
# 15    1651675
# Name: 2022년12월_남자 인구수, dtype: int64

# %%
woman_total = './pop/womanPop_2022.csv'
woman_total_data=pd.read_csv(woman_total)
woman_total_data.head()
# Out:
#     행정구역  2022년1월_여자 인구수  2022년2월_여자 인구수  2022년3월_여자 인구수  2022년4월_여자 인구수  \
# 0  서울특별시         4890295         4892628         4892868         4890398
# 1  부산광역시         1710667         1710285         1708546         1707044
# 2  대구광역시         1209191         1208056         1207862         1207122
# 3  인천광역시         1472487         1473546         1474427         1474746
# 4  광주광역시          728599          727833          727174          726392
#
#    2022년5월_여자 인구수  2022년6월_여자 인구수  2022년7월_여자 인구수  2022년8월_여자 인구수  \
# 0         4889447         4889152         4888806         4887159
# 1         1706342         1705793         1704952         1703623
# 2         1206367         1205735         1205275         1204372
# 3         1475739         1476634         1478403         1479747
# 4          725950          725693          725398          725307
#
#    2022년9월_여자 인구수  2022년10월_여자 인구수  2022년11월_여자 인구수  2022년12월_여자 인구수  \
# 0         4868407          4865263          4862055          4858324
# 1         1700042          1699537          1698790          1697897
# 2         1202409          1202124          1201595          1200826
# 3         1478201          1479362          1480717          1482139
# 4          724608           724532           724234           723751
#
#           위도          경도
# 0  37.566491  126.977945
# 1  35.179805  129.074774
# 2  35.872873  128.601429
# 3  37.456191  126.705228
# 4  35.160198  126.851297

# %%
w_tenmillion_df= woman_total_data[woman_total_data['2022년12월_여자 인구수'] >= 1000000][['행정구역', '2022년12월_여자 인구수']]
w_tenmillion_df

plt.rc('font', family='Apple SD Gothic Neo')
plt.bar(w_tenmillion_df['행정구역'], w_tenmillion_df['2022년12월_여자 인구수'], color='blue', alpha=0.5)
# Out:
# <BarContainer object of 8 artists>

# %%
months = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
woman_total_data_list = []
for month in months:
    column_name = f'2022년{month}_여자 인구수'
    woman_total_data_list.append(woman_total_data[column_name].sum())

plt.plot(months, woman_total_data_list, color = 'orange', marker = '*')
plt.title('2022 여자 총 인구수 변동')
# Out:
# Text(0.5, 1.0, '2022 여자 총 인구수 변동')

# %%
w_ratio= w_tenmillion_df['2022년12월_여자 인구수']
w_labels = w_tenmillion_df['행정구역']

plt.pie(w_ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
plt.plot(months, woman_total_data_list, label='woman')
plt.plot(months, man_total_data_list, label='man')
plt.legend()

plt.title('2022 남자/여자 총 인구수 변동')
# Out:
# Text(0.5, 1.0, '2022 남자/여자 총 인구수 변동')

# %%
fig, axes = plt.subplots(1,2)

plt.title('지역별 남/여 분포도 (좌측부터 남/여)')
axes[0].pie(ratio, labels=labels, autopct='%.1f%%')
axes[1].pie(w_ratio, labels=labels, autopct='%.1f%%')

plt.show()

# 지방의 경우 남자에 비해 여자가 대구,부산과 같은 광역시에 더 모여있는 것을 확인.
# 수도권의 경우 남자에 비해 여자가 경기도보다 서울에 더 모여있는 것을 확인.
